# %%
# !pip install wordcloud
# !pip install textblob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
TRAIN_CSV = '/content/drive/MyDrive/440_proj/Question_Answer_Classification_Dataset.csv'
TEST_CSV = '/content/drive/MyDrive/440_proj/Updated_Question_Answer_Classification_Dataset_Test.csv'

# %% [markdown]
# ## Initial Imports

# %%
import os
import re
import string
from collections import Counter, defaultdict

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split

import nltk
from nltk.corpus import stopwords

from wordcloud import WordCloud

# %%
nltk.download("punkt")
nltk.download('punkt_tab')
nltk.download("stopwords")

stop_words = stopwords.words("english")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Loading The Datasets

# %%
train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

train_df.head()
# Out:
# Train shape: (280003, 2)
# Test shape: (59999, 2)
#                                              QA Text                  Class
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet

# %% [markdown]
# ## Basic Comprehensive Checks Utility Function (On Originals)

# %%
def basic_checks(df, name="Dataset"):
    print(f"== {name} BASIC CHECKS ==")
    print("Shape:", df.shape)
    print("Columns:", df.columns.tolist())
    print("\nMissing values per column:")
    print(df.isnull().sum())
    print("\nDuplicate rows:", df.duplicated().sum())
    if "Class" in df.columns:
        print("\nClass distribution (All 10):")
        print(df["Class"].value_counts().head(10))
    print("-"*40)


basic_checks(train_df, "TRAIN ORIGINAL")
basic_checks(test_df, "TEST ORIGINAL")
# Out:
# == TRAIN ORIGINAL BASIC CHECKS ==
# Shape: (280003, 2)
# Columns: ['QA Text', 'Class']
#
# Missing values per column:
# QA Text    0
# Class      0
# dtype: int64
#
# Duplicate rows: 0
#
# Class distribution (All 10):
# Class
# Entertainment & Music     28267
# Health                    28186
# Sports                    28074
# Science & Mathematics     28039
# Computers & Internet      27980
# Education & Reference     27972
# Business & Finance        27953
# Family & Relationships    27905
# Society & Culture         27881
# Politics & Government     27746
# Name: count, dtype: int64
# ----------------------------------------
# == TEST ORIGINAL BASIC CHECKS ==
# Shape: (59999, 2)
# Columns: ['QA Text', 'Class']
#
# Missing values per column:
# QA Text    0
# Class      0
# dtype: int64
#
# Duplicate rows: 0
#
# Class distribution (All 10):
# Class
# Science & Mathematics     6000
# Education & Reference     6000
# Health                    6000
# Computers & Internet      6000
# Entertainment & Music     6000
# Business & Finance        6000
# Society & Culture         6000
# Politics & Government     6000
# Sports                    6000
# Family & Relationships    5999
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# ## QA Text parser (utility function)

# %%
import numpy as np

def split_qa_text(s):
    if pd.isna(s):
        return pd.Series([np.nan, np.nan, np.nan])
    s = str(s).strip()
    pattern = re.compile(
        r"Question Title:\s*(.*?)\s*Question Content:\s*(.*?)\s*Best Answer:\s*(.*)",
        re.DOTALL | re.IGNORECASE
    )
    m = pattern.search(s)
    if m:
        title, content, answer = m.group(1).strip(), m.group(2).strip(), m.group(3).strip()
        # replace empty with NaN
        title = title if title else np.nan
        content = content if content else np.nan
        answer = answer if answer else np.nan
        return pd.Series([title, content, answer])
    return pd.Series([np.nan, np.nan, np.nan])

# %% [markdown]
# # Preprocessing p1

# %% [markdown]
# ## Apply QA Text Parser to Dataset

# %%
import time


start_time = time.time()

train_df[["question_title","question_content","best_answer"]] = train_df["QA Text"].apply(
    lambda x: pd.Series(split_qa_text(x))
)

test_df[["question_title","question_content","best_answer"]] = test_df["QA Text"].apply(
    lambda x: pd.Series(split_qa_text(x))
)

# making a merged 'full_text' col as well
def merge_parsed(the_df):
  for df in [the_df]:
      df["full_text"] = (
          df["question_title"].fillna("") + " " +
          df["question_content"].fillna("") + " " +
          df["best_answer"].fillna("")
      ).str.strip()

merge_parsed(train_df)
merge_parsed(test_df)

end_time = time.time()
print(f"Time taken: {end_time - start_time} seconds")

train_df.head()
# Out:
# Time taken: 60.88877892494202 seconds
#                                              QA Text                  Class  \
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet
#
#                                       question_title  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2          Is brother Jesus our brother or our King?
# 3                                      what is I-20?
# 4                               what is a data disk?
#
#                                     question_content  \
# 0                                         web design
# 1  What do they do for sure.  I would like to be ...
# 2                                                NaN
# 3  students need I 20 for being admitted in Unive...
# 4  I heard that it is possible to save files on a...
#
#                                          best_answer  \
# 0  Hey!  Re. Job. I tried to e-mail you using the...
# 1  Medical Illustrator\nMedical Illustrator. Medi...
# 2  the all being one, i'd say he's our brother. y...
# 3  an I 20 is a form that the university will giv...
# 4  i think it's a usb flashdrive. a  small, light...
#
#                                            full_text
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2  Is brother Jesus our brother or our King?  the...
# 3  what is I-20? students need I 20 for being adm...
# 4  what is a data disk? I heard that it is possib...

# %%
test_df.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\nWhy does Zebras have stripes?...  Science & Mathematics
# 1  Question Title:\nWhat did the itsy bitsy sipde...  Education & Reference
# 2  Question Title:\nWhat is the difference betwee...  Education & Reference
# 3  Question Title:\nWhy do women get PMS?\nQuesti...                 Health
# 4  Question Title:\nIf your co-worker is guilty o...                 Health
#
#                                       question_title  \
# 0                      Why does Zebras have stripes?
# 1           What did the itsy bitsy sipder climb up?
# 2  What is the difference between a Bachelors and...
# 3                              Why do women get PMS?
# 4  If your co-worker is guilty of unsanitary hygi...
#
#                                     question_content  \
# 0  What is the purpose or those stripes? Who do t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          best_answer  \
# 0  this provides camouflage - predator vision is ...
# 1                                         waterspout
# 2  One difference between a Bachelors and a Maste...
# 3  Premenstrual syndrome (PMS) is a group of symp...
# 4  Yes, it is your obligation. Especially if it i...
#
#                                            full_text
# 0  Why does Zebras have stripes? What is the purp...
# 1  What did the itsy bitsy sipder climb up?  wate...
# 2  What is the difference between a Bachelors and...
# 3  Why do women get PMS?  Premenstrual syndrome (...
# 4  If your co-worker is guilty of unsanitary hygi...

# %% [markdown]
# ## Original QA Text vs full_text

# %%
original_cell_value = test_df.iloc[0, 0]
print("Original Cell Value\n", original_cell_value)
cell_value = test_df.iloc[0, 5]
print("\nCell Value\n", cell_value)
# Out:
# Original Cell Value
#  Question Title:
# Why does Zebras have stripes?
# Question Content:
# What is the purpose or those stripes? Who do they serve the Zebras in the wild life?
# Best Answer:
# this provides camouflage - predator vision is such that it is usually difficult for them to see complex patterns
#
# Cell Value
#  Why does Zebras have stripes? What is the purpose or those stripes? Who do they serve the Zebras in the wild life? this provides camouflage - predator vision is such that it is usually difficult for them to see complex patterns

# %% [markdown]
# ## Basic Comprehensive Checks (After Preprocess p1)

# %%
print("AFTER PRE-PROCESSING USER PARSER")
basic_checks(train_df, "TRAIN PARSED")
print()
basic_checks(test_df, "TEST PARSED")
# Out:
# AFTER PRE-PROCESSING USER PARSER
# == TRAIN PARSED BASIC CHECKS ==
# Shape: (280003, 6)
# Columns: ['QA Text', 'Class', 'question_title', 'question_content', 'best_answer', 'full_text']
#
# Missing values per column:
# QA Text                  0
# Class                    0
# question_title           0
# question_content    126776
# best_answer           5006
# full_text                0
# dtype: int64
#
# Duplicate rows: 0
#
# Class distribution (All 10):
# Class
# Entertainment & Music     28267
# Health                    28186
# Sports                    28074
# Science & Mathematics     28039
# Computers & Internet      27980
# Education & Reference     27972
# Business & Finance        27953
# Family & Relationships    27905
# Society & Culture         27881
# Politics & Government     27746
# Name: count, dtype: int64
# ----------------------------------------
#
# == TEST PARSED BASIC CHECKS ==
# Shape: (59999, 6)
# Columns: ['QA Text', 'Class', 'question_title', 'question_content', 'best_answer', 'full_text']
#
# Missing values per column:
# QA Text                 0
# Class                   0
# question_title          0
# question_content    27106
# best_answer          1034
# full_text               0
# dtype: int64
#
# Duplicate rows: 0
#
# Class distribution (All 10):
# Class
# Science & Mathematics     6000
# Education & Reference     6000
# Health                    6000
# Computers & Internet      6000
# Entertainment & Music     6000
# Business & Finance        6000
# Society & Culture         6000
# Politics & Government     6000
# Sports                    6000
# Family & Relationships    5999
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# ## Fill the Missing Values

# %%
def fill_missing(df):
    df['question_title'] = df['question_title'].fillna("")
    df['question_content'] = df['question_content'].fillna("")
    df['best_answer'] = df['best_answer'].fillna("")
    df['full_text'] = (
        df['question_title'] + " " +
        df['question_content'] + " " +
        df['best_answer']
    ).str.strip()
    return df


train_df_filled = fill_missing(train_df)
test_df_filled = fill_missing(test_df)

test_df_filled.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\nWhy does Zebras have stripes?...  Science & Mathematics
# 1  Question Title:\nWhat did the itsy bitsy sipde...  Education & Reference
# 2  Question Title:\nWhat is the difference betwee...  Education & Reference
# 3  Question Title:\nWhy do women get PMS?\nQuesti...                 Health
# 4  Question Title:\nIf your co-worker is guilty o...                 Health
#
#                                       question_title  \
# 0                      Why does Zebras have stripes?
# 1           What did the itsy bitsy sipder climb up?
# 2  What is the difference between a Bachelors and...
# 3                              Why do women get PMS?
# 4  If your co-worker is guilty of unsanitary hygi...
#
#                                     question_content  \
# 0  What is the purpose or those stripes? Who do t...
# 1
# 2
# 3
# 4
#
#                                          best_answer  \
# 0  this provides camouflage - predator vision is ...
# 1                                         waterspout
# 2  One difference between a Bachelors and a Maste...
# 3  Premenstrual syndrome (PMS) is a group of symp...
# 4  Yes, it is your obligation. Especially if it i...
#
#                                            full_text
# 0  Why does Zebras have stripes? What is the purp...
# 1  What did the itsy bitsy sipder climb up?  wate...
# 2  What is the difference between a Bachelors and...
# 3  Why do women get PMS?  Premenstrual syndrome (...
# 4  If your co-worker is guilty of unsanitary hygi...

# %% [markdown]
# ## Compare Class Distributions Train VS Test

# %%
print("Train class counts:")
display(train_df["Class"].value_counts().sort_index())
print("Test class counts:")
display(test_df["Class"].value_counts().sort_index())

# quick normalized bar plot
plt.figure(figsize=(10,6))
train_counts = train_df["Class"].value_counts(normalize=True).sort_index()
test_counts  = test_df["Class"].value_counts(normalize=True).sort_index()
comp = pd.concat([train_counts, test_counts], axis=1, keys=["train_pct","test_pct"]).fillna(0)
comp.plot.bar(figsize=(12,6))
plt.title("Train vs Test class proportions")
plt.show()
# Out:
# Train class counts:
# Class
# Business & Finance        27953
# Computers & Internet      27980
# Education & Reference     27972
# Entertainment & Music     28267
# Family & Relationships    27905
# Health                    28186
# Politics & Government     27746
# Science & Mathematics     28039
# Society & Culture         27881
# Sports                    28074
# Name: count, dtype: int64
# Test class counts:
# Class
# Business & Finance        6000
# Computers & Internet      6000
# Education & Reference     6000
# Entertainment & Music     6000
# Family & Relationships    5999
# Health                    6000
# Politics & Government     6000
# Science & Mathematics     6000
# Society & Culture         6000
# Sports                    6000
# Name: count, dtype: int64

# %% [markdown]
# ## Component-wise length stats (chars, words, sentences)

# %%
def add_length_features(df, col):
    df[f"{col}_char_count"] = df[col].fillna("").astype(str).apply(len)
    df[f"{col}_word_count"] = df[col].fillna("").astype(str).apply(lambda x: len(x.split()))
    df[f"{col}_sent_count"] = df[col].fillna("").astype(str).apply(lambda x: len(nltk.sent_tokenize(x)))

updated_train_df = train_df_filled.copy()
updated_test_df = test_df_filled.copy()
for col in ["question_title","question_content","best_answer","full_text"]:
    add_length_features(updated_train_df, col)
    add_length_features(updated_test_df, col)


updated_train_df[["question_title_word_count","question_content_word_count","best_answer_word_count","full_text_word_count"]].describe().T
# Out:
#                                 count       mean        std  min   25%   50%  \
# question_title_word_count    280003.0  10.729028   5.326170  1.0   7.0  10.0
# question_content_word_count  280003.0  21.615940  37.714632  0.0   0.0   5.0
# best_answer_word_count       280003.0  58.994982  85.527328  0.0  12.0  31.0
# full_text_word_count         280003.0  91.339950  98.239520  1.0  31.0  60.0
#
#                                75%     max
# question_title_word_count     14.0    39.0
# question_content_word_count   29.0   837.0
# best_answer_word_count        71.0  1169.0
# full_text_word_count         114.0  1334.0

# %%
updated_train_df.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet
#
#                                       question_title  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2          Is brother Jesus our brother or our King?
# 3                                      what is I-20?
# 4                               what is a data disk?
#
#                                     question_content  \
# 0                                         web design
# 1  What do they do for sure.  I would like to be ...
# 2
# 3  students need I 20 for being admitted in Unive...
# 4  I heard that it is possible to save files on a...
#
#                                          best_answer  \
# 0  Hey!  Re. Job. I tried to e-mail you using the...
# 1  Medical Illustrator\nMedical Illustrator. Medi...
# 2  the all being one, i'd say he's our brother. y...
# 3  an I 20 is a form that the university will giv...
# 4  i think it's a usb flashdrive. a  small, light...
#
#                                            full_text  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2  Is brother Jesus our brother or our King?  the...
# 3  what is I-20? students need I 20 for being adm...
# 4  what is a data disk? I heard that it is possib...
#
#    question_title_char_count  question_title_word_count  \
# 0                         74                         16
# 1                         78                         14
# 2                         41                          8
# 3                         13                          3
# 4                         20                          5
#
#    question_title_sent_count  question_content_char_count  \
# 0                          2                           10
# 1                          2                          122
# 2                          1                            0
# 3                          1                           94
# 4                          1                          210
#
#    question_content_word_count  question_content_sent_count  \
# 0                            2                            1
# 1                           25                            2
# 2                            0                            0
# 3                           19                            1
# 4                           44                            4
#
#    best_answer_char_count  best_answer_word_count  best_answer_sent_count  \
# 0                     319                      57                       6
# 1                    1652                     164                       4
# 2                      71                      14                       2
# 3                     203                      40                       3
# 4                     217                      43                       3
#
#    full_text_char_count  full_text_word_count  full_text_sent_count
# 0                   405                    75                     8
# 1                  1854                   203                     8
# 2                   114                    22                     3
# 3                   312                    62                     5
# 4                   449                    92                     8

# %% [markdown]
# ## Visualize Length Distributions (word counts) component-wise

# %%
plt.figure(figsize=(14,8))
cols = ["question_title_word_count","question_content_word_count","best_answer_word_count","full_text_word_count"]
for i, c in enumerate(cols,1):
    plt.subplot(2,2,i)
    sns.histplot(updated_train_df[c], bins=60, kde=True)
    plt.title(c)
plt.tight_layout()
plt.show()

# Boxplot to show outliers for full_text
plt.figure(figsize=(8,3))
sns.boxplot(x=updated_train_df["full_text_word_count"])
plt.title("Full text word count boxplot (outliers)")
plt.show()

# %% [markdown]
# ## Lexical Diversity

# %%
def lexical_diversity(text):
  t = str(text).split()
  if len(t) == 0:
      return 0.0
  return len(set(t))/len(t)


for col in ["question_title","question_content","best_answer","full_text"]:
    updated_train_df[f"{col}_lexical_diversity"] = updated_train_df[col].astype(str).apply(lexical_diversity)
    updated_test_df[f"{col}_lexical_diversity"] = updated_test_df[col].astype(str).apply(lexical_diversity)

updated_train_df[[c for c in updated_train_df.columns if "lexical_diversity" in c]].describe().T
# Out:
#                                        count      mean       std       min  \
# question_title_lexical_diversity    280003.0  0.970065  0.055042  0.142857
# question_content_lexical_diversity  280003.0  0.481104  0.445576  0.000000
# best_answer_lexical_diversity       280003.0  0.842478  0.172387  0.000000
# full_text_lexical_diversity         280003.0  0.798107  0.125245  0.014778
#
#                                          25%       50%       75%  max
# question_title_lexical_diversity    0.944444  1.000000  1.000000  1.0
# question_content_lexical_diversity  0.000000  0.705426  0.911111  1.0
# best_answer_lexical_diversity       0.759036  0.873239  1.000000  1.0
# full_text_lexical_diversity         0.707865  0.800000  0.894737  1.0

# %% [markdown]
# ## Detect URLs, emails, and HTML tags presence as features (Preprocess p2)

# %%
def detect_features(text):
  url_re = re.compile(r"http[s]?://|www\.")
  email_re = re.compile(r"\S+@\S+\.\S+")
  html_re = re.compile(r"<[^>]+>")
  t = str(text)

  return {
      "has_url": bool(url_re.search(t)),
      "has_email": bool(email_re.search(t)),
      "has_html": bool(html_re.search(t)),
      "num_qmarks": t.count("?"),
      "num_exclaims": t.count("!"),
  }


feat_df = updated_train_df["QA Text"].apply(lambda x: pd.Series(detect_features(x)))
updated_train_df = pd.concat([updated_train_df, feat_df], axis=1)

test_feat_df = updated_test_df["QA Text"].apply(lambda x: pd.Series(detect_features(x)))
updated_test_df = pd.concat([updated_test_df, test_feat_df], axis=1)

updated_train_df[["has_url","has_email","has_html","num_qmarks","num_exclaims"]].sum()
# Out:
# has_url          25850
# has_email         2217
# has_html           960
# num_qmarks      533113
# num_exclaims    208104
# dtype: int64

# %%
updated_train_df.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet
#
#                                       question_title  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2          Is brother Jesus our brother or our King?
# 3                                      what is I-20?
# 4                               what is a data disk?
#
#                                     question_content  \
# 0                                         web design
# 1  What do they do for sure.  I would like to be ...
# 2
# 3  students need I 20 for being admitted in Unive...
# 4  I heard that it is possible to save files on a...
#
#                                          best_answer  \
# 0  Hey!  Re. Job. I tried to e-mail you using the...
# 1  Medical Illustrator\nMedical Illustrator. Medi...
# 2  the all being one, i'd say he's our brother. y...
# 3  an I 20 is a form that the university will giv...
# 4  i think it's a usb flashdrive. a  small, light...
#
#                                            full_text  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2  Is brother Jesus our brother or our King?  the...
# 3  what is I-20? students need I 20 for being adm...
# 4  what is a data disk? I heard that it is possib...
#
#    question_title_char_count  question_title_word_count  \
# 0                         74                         16
# 1                         78                         14
# 2                         41                          8
# 3                         13                          3
# 4                         20                          5
#
#    question_title_sent_count  question_content_char_count  ...  \
# 0                          2                           10  ...
# 1                          2                          122  ...
# 2                          1                            0  ...
# 3                          1                           94  ...
# 4                          1                          210  ...
#
#    full_text_sent_count  question_title_lexical_diversity  \
# 0                     8                            0.9375
# 1                     8                            1.0000
# 2                     3                            0.7500
# 3                     5                            1.0000
# 4                     8                            1.0000
#
#    question_content_lexical_diversity  best_answer_lexical_diversity  \
# 0                            1.000000                       0.754386
# 1                            0.920000                       0.640244
# 2                            0.000000                       1.000000
# 3                            0.842105                       0.800000
# 4                            0.818182                       0.837209
#
#    full_text_lexical_diversity  has_url  has_email  has_html  num_qmarks  \
# 0                     0.773333    False       True     False           1
# 1                     0.660099     True      False      True           3
# 2                     0.863636    False      False     False           1
# 3                     0.677419    False      False     False           2
# 4                     0.717391    False      False     False           2
#
#    num_exclaims
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Top tokens overall & helper functions (uses simple cleaning)

# %%
from sklearn.feature_extraction.text import CountVectorizer


def get_top_n_words(corpus, n=20, ng_range=(1,1), stopwords=None):
    vect = CountVectorizer(ngram_range=ng_range, stop_words=stopwords, min_df=1)
    X = vect.fit_transform(corpus.astype(str))
    sums = np.array(X.sum(axis=0)).flatten()
    terms = np.array(vect.get_feature_names_out())
    top_idxs = sums.argsort()[::-1][:n]
    return list(zip(terms[top_idxs], sums[top_idxs]))


print("Top words in full_text (raw):")
print(get_top_n_words(updated_train_df["full_text"], n=30, ng_range=(1,1), stopwords=stop_words)[:30])
# Out:
# Top words in full_text (raw):
# [('like', np.int64(89810)), ('get', np.int64(87187)), ('would', np.int64(81658)), ('one', np.int64(79648)), ('know', np.int64(76279)), ('people', np.int64(60555)), ('think', np.int64(60192)), ('want', np.int64(52886)), ('good', np.int64(52466)), ('go', np.int64(50864)), ('time', np.int64(50694)), ('need', np.int64(46094)), ('help', np.int64(44103)), ('make', np.int64(41703)), ('com', np.int64(41152)), ('also', np.int64(40103)), ('really', np.int64(38134)), ('way', np.int64(35931)), ('find', np.int64(35765)), ('see', np.int64(33264)), ('could', np.int64(32814)), ('www', np.int64(32075)), ('many', np.int64(31151)), ('best', np.int64(31034)), ('much', np.int64(30559)), ('work', np.int64(29608)), ('use', np.int64(29548)), ('first', np.int64(29334)), ('take', np.int64(28697)), ('love', np.int64(28497))]

# %% [markdown]
# ## Top words per class (show top 10 for each class)

# %%
def top_per_class(df, text_col="full_text", label_col="Class", top_n=10, ng=(1,1)):
    classes = df[label_col].unique()
    result = {}
    for cl in sorted(classes):
        subset = df[df[label_col]==cl]
        top = get_top_n_words(subset[text_col], n=top_n, ng_range=ng, stopwords=stop_words)
        result[cl] = top
    return result


top1 = top_per_class(updated_train_df, text_col="question_title", top_n=10, ng=(1,1))
for cl, toks in top1.items():
    print(f"\n=== {cl} ===")
    print(toks)
# Out:
# === Business & Finance ===
# [('get', np.int64(2158)), ('find', np.int64(1639)), ('know', np.int64(1233)), ('anyone', np.int64(1143)), ('need', np.int64(1140)), ('job', np.int64(1127)), ('would', np.int64(1000)), ('business', np.int64(999)), ('money', np.int64(969)), ('best', np.int64(968))]
#
# === Computers & Internet ===
# [('computer', np.int64(2742)), ('get', np.int64(2468)), ('yahoo', np.int64(2114)), ('help', np.int64(1540)), ('free', np.int64(1406)), ('internet', np.int64(1317)), ('know', np.int64(1255)), ('find', np.int64(1191)), ('windows', np.int64(1188)), ('anyone', np.int64(1060))]
#
# === Education & Reference ===
# [('help', np.int64(1780)), ('school', np.int64(1502)), ('get', np.int64(1316)), ('need', np.int64(1261)), ('know', np.int64(1187)), ('find', np.int64(1102)), ('anyone', np.int64(999)), ('good', np.int64(932)), ('please', np.int64(903)), ('college', np.int64(859))]
#
# === Entertainment & Music ===
# [('song', np.int64(2969)), ('anyone', np.int64(2008)), ('know', np.int64(1706)), ('movie', np.int64(1698)), ('think', np.int64(1461)), ('like', np.int64(1414)), ('name', np.int64(1258)), ('music', np.int64(1165)), ('get', np.int64(1077)), ('would', np.int64(1039))]
#
# === Family & Relationships ===
# [('love', np.int64(2647)), ('like', np.int64(2492)), ('get', np.int64(1889)), ('girl', np.int64(1883)), ('guy', np.int64(1834)), ('know', np.int64(1630)), ('help', np.int64(1510)), ('friend', np.int64(1443)), ('guys', np.int64(1398)), ('sex', np.int64(1294))]
#
# === Health ===
# [('get', np.int64(2369)), ('help', np.int64(1477)), ('anyone', np.int64(1331)), ('weight', np.int64(1294)), ('know', np.int64(1124)), ('best', np.int64(1104)), ('way', np.int64(869)), ('good', np.int64(862)), ('like', np.int64(784)), ('lose', np.int64(725))]
#
# === Politics & Government ===
# [('think', np.int64(1793)), ('bush', np.int64(1662)), ('would', np.int64(1348)), ('people', np.int64(1273)), ('president', np.int64(1268)), ('get', np.int64(1231)), ('us', np.int64(1187)), ('war', np.int64(1023)), ('iraq', np.int64(845)), ('know', np.int64(782))]
#
# === Science & Mathematics ===
# [('help', np.int64(1219)), ('would', np.int64(790)), ('water', np.int64(787)), ('find', np.int64(783)), ('many', np.int64(776)), ('earth', np.int64(714)), ('know', np.int64(708)), ('one', np.int64(694)), ('please', np.int64(682)), ('need', np.int64(630))]
#
# === Society & Culture ===
# [('people', np.int64(2286)), ('god', np.int64(1983)), ('think', np.int64(1462)), ('would', np.int64(1386)), ('know', np.int64(1089)), ('anyone', np.int64(1009)), ('like', np.int64(990)), ('jesus', np.int64(918)), ('get', np.int64(852)), ('one', np.int64(845))]
#
# === Sports ===
# [('world', np.int64(2545)), ('cup', np.int64(2342)), ('think', np.int64(1780)), ('team', np.int64(1688)), ('win', np.int64(1662)), ('best', np.int64(1515)), ('football', np.int64(1421)), ('get', np.int64(1080)), ('anyone', np.int64(1041)), ('player', np.int64(949))]

# %% [markdown]
# ## Top bigrams/trigrams for a specific class example

# %%
example_class = updated_train_df["Class"].dropna().unique()[0]  # pick first class as example
print("Example class:", example_class)
print("Top bigrams:", get_top_n_words(updated_train_df[train_df["Class"]==example_class]["full_text"], n=20, ng_range=(2,2), stopwords=stop_words))
print("Top trigrams:", get_top_n_words(updated_train_df[train_df["Class"]==example_class]["full_text"], n=20, ng_range=(3,3), stopwords=stop_words))
# Out:
# Example class: Business & Finance
# Top bigrams: [('http www', np.int64(2096)), ('nhttp www', np.int64(2070)), ('would like', np.int64(898)), ('credit card', np.int64(872)), ('real estate', np.int64(841)), ('good luck', np.int64(766)), ('yahoo com', np.int64(676)), ('ngood luck', np.int64(675)), ('make sure', np.int64(608)), ('anyone know', np.int64(545)), ('make money', np.int64(494)), ('best way', np.int64(473)), ('small business', np.int64(445)), ('com nhttp', np.int64(405)), ('want know', np.int64(392)), ('web site', np.int64(392)), ('credit report', np.int64(363)), ('get job', np.int64(335)), ('need know', np.int64(324)), ('please help', np.int64(324))]
# Top trigrams: [('com nhttp www', np.int64(340)), ('www powerhomebiz com', np.int64(224)), ('http www powerhomebiz', np.int64(177)), ('www sba gov', np.int64(171)), ('would like know', np.int64(166)), ('wikipedia org wiki', np.int64(149)), ('en wikipedia org', np.int64(148)), ('http www sba', np.int64(133)), ('answers yahoo com', np.int64(113)), ('scam scam scam', np.int64(95)), ('real estate agent', np.int64(94)), ('com http www', np.int64(93)), ('www grants gov', np.int64(92)), ('www cfda gov', np.int64(90)), ('yahoo com question', np.int64(90)), ('website http www', np.int64(90)), ('nhttp answers yahoo', np.int64(90)), ('http en wikipedia', np.int64(85)), ('html nhttp www', np.int64(79)), ('federal domestic assistance', np.int64(71))]

# %% [markdown]
# ## Wordcloud per-class

# %%
def plot_wordclouds_in_grid(df, classes_to_plot, rows=2, cols=2, max_words=150):
    fig, axes = plt.subplots(rows, cols, figsize=(20, 10))
    axes = axes.flatten()  # Flatten the 2x2 array of axes for easy iteration

    wc = WordCloud(width=800, height=400, background_color="white", max_words=max_words, random_state=42)

    # Loop through the classes and plot each word cloud in its own subplot
    for i, cl in enumerate(classes_to_plot):
        if i >= len(axes):
            break # Stop if we run out of subplots

        text_data = df[df["Class"] == cl]["full_text"].astype(str)
        text_string = " ".join(text_data.values)

        wc.generate(text_string)

        # Plot on the current subplot
        axes[i].imshow(wc, interpolation="bilinear")
        count = len(text_data)
        axes[i].set_title(f"Wordcloud — {cl} (n={count})", fontsize=14)

    # If there are empty subplots, hide them
    for i in range(len(classes_to_plot), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.show()


top_classes = updated_train_df["Class"].value_counts().head(4).index.tolist()
plot_wordclouds_in_grid(updated_train_df, top_classes, rows=2, cols=2)

# %%
# Todos:
# verify both the wordcloud implementations.

# %% [markdown]
# ## Outliers: shortest & longest examples per component

# %%
for col in ["question_title","question_content","best_answer","full_text"]:
    wc = f"{col}_word_count"
    idx_min = updated_train_df[wc].idxmin()
    idx_max = updated_train_df[wc].idxmax()
    print(f"\n== {col} ==")
    print("Shortest (len={}):\n".format(updated_train_df.loc[idx_min, wc]), updated_train_df.loc[idx_min, col])
    print("\nLongest (len={}):\n".format(updated_train_df.loc[idx_max, wc]), updated_train_df.loc[idx_max, col][:1000], "...\n")
# Out:
# == question_title ==
# Shortest (len=1):
#  white&nerdy?
#
# Longest (len=39):
#  d d d d does  c c c c coffee  g g g g g g give  y y y y you  t t t t t the  j j j j jitters  t t t t t too? ...
#
#
# == question_content ==
# Shortest (len=0):
#
#
# Longest (len=837):
#  I warn you now this LONG. So long in fact I had to type it up in word and cut and paste so that I didn’t have to keep going back and adding details. I know this is probably against the rules, but I’m sorry, really sorry…Hope you can suffer though this and read it, I really need the help. Thanks in advance.\nLast year I was working at Hobby Lobby. Well while on the job I hurt my back. I kept telling the boss and the assistant manager that my back hurt and I needed to go home. They kept telling me that I would be ok and that I needed to stay until closing time. Well I somehow made it through the day. Well that night I couldn’t sleep. I couldn’t stand and I couldn’t set for more than a minute or two at a time. It was horrible. Well come morning I call the manager and told him that my back hurt and I wouldn’t be able to come to work. He told me that if my back hurt that I would have to go to the Chiropractor and get a work release before I could even come back to work. I however was tight  ...
#
#
# == best_answer ==
# Shortest (len=0):
#
#
# Longest (len=1169):
#  T1 - Jim Furyk -7 F -7 65 - - - 65 \nT1 - Davis Love III -7 F -7 65 - - - 65 \nT3 - Robert Allenby* -5 F -5 67 - - - 67 \nT3 - Bernhard Langer -5 F -5 67 - - - 67 \nT5 - Arron Oberholser* -4 F -4 68 - - - 68 \nT5 - Ben Crane -4 F -4 68 - - - 68 \nT5 - Jose Maria Olazabal* -4 F -4 68 - - - 68 \nT5 - John Rollins -4 F -4 68 - - - 68 \nT5 - Vijay Singh -4 F -4 68 - - - 68 \nT5 - Miguel A. Jimenez -4 17 -4 - - - - - \nT5 - Bo Van Pelt -4 17 -4 - - - - - \nT12 - Joe Durant -3 F -3 69 - - - 69 \nT12 - Rocco Mediate* -3 F -3 69 - - - 69 \nT12 - Steve Flesch -3 F -3 69 - - - 69 \nT12 - Olin Browne* -3 F -3 69 - - - 69 \nT12 - Retief Goosen* -3 F -3 69 - - - 69 \nT12 - Mark Calcavecchia -3 F -3 69 - - - 69 \nT12 - Thomas Bjorn -3 F -3 69 - - - 69 \nT12 - Billy Andrade -3 F -3 69 - - - 69 \nT12 - Fredrik Jacobson -3 F -3 69 - - - 69 \nT12 - K.J. Choi* -3 F -3 69 - - - 69 \nT12 - Fred Couples -3 F -3 69 - - - 69 \nT12 - Henrik Stenson* -3 16 -3 - - - - - \nT24 - Brian Davis* -2 F -2 70 - - - 70 \ ...
#
#
# == full_text ==
# Shortest (len=1):
#  clayparklabs?
#
# Longest (len=1334):
#  Somehow I came across a very Interesting website made by an atheist (I'm a theist), I thought It was a hoax bu 1) The Genesis 1 creation account conflicts with the order of events that are known to science. Genesis 1:1 The earth is created before light and stars, birds and whales before reptiles and insects, and flowering plants before any animals.  From science, we know that the true order of events was just the opposite.\n\n2) “And God said, Let there be light” (Genesis 1:3) and “. . .And the evening and the morning were the first day” (Genesis 1 :5), versus “And God said, ‘Let there be light in the firmament of the heaven to divide the day from the night....’ “And God made two lights; the greater light to rule the day, and the lesser light to rule the night: he made the stars also…  And the evening and morning were the fourth day” (Genesis 1 :14-19).  These violates two major facts.  Light cannot exist without a sun, and secondly, how can morning be distinguished from evening unless ...

# %% [markdown]
# ## Save parsed CSV and summary stats

# %%
# OUT_DIR = "eda_outputs"
# os.makedirs(OUT_DIR, exist_ok=True)
# train_df.to_csv(os.path.join(OUT_DIR, "train_parsed.csv"), index=False)
# updated_train_df.to_csv(os.path.join(OUT_DIR, "uptaded_train_parsed.csv"), index=False)
# print("Saved parsed train to", os.path.join(OUT_DIR, "train_parsed.csv"))
# print("Saved parsed train to", os.path.join(OUT_DIR, "uptaded_train_parsed.csv"))

# # Save a simple stats CSV for quick reference
# stats = {}
# stats["n_samples"] = len(train_df)
# stats["n_classes"] = train_df["Class"].nunique()
# stats["class_counts"] = train_df["Class"].value_counts().to_dict()
# pd.DataFrame.from_dict(stats, orient="index").to_csv(os.path.join(OUT_DIR, "train_basic_stats.csv"))
# print("Saved basic stats to", os.path.join(OUT_DIR, "train_basic_stats.csv"))


# test_df.to_csv(os.path.join(OUT_DIR, "test_parsed.csv"), index=False)
# updated_test_df.to_csv(os.path.join(OUT_DIR, "uptaded_test_parsed.csv"), index=False)
# # Save a simple stats CSV for quick reference
# stats = {}
# stats["n_samples"] = len(test_df)
# stats["n_classes"] = test_df["Class"].nunique()
# stats["class_counts"] = test_df["Class"].value_counts().to_dict()
# pd.DataFrame.from_dict(stats, orient="index").to_csv(os.path.join(OUT_DIR, "test_basic_stats.csv"))
# print("Saved basic stats to", os.path.join(OUT_DIR, "test_basic_stats.csv"))
# Out:
# Saved basic stats to eda_outputs/test_basic_stats.csv

# %%
train_df.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet
#
#                                       question_title  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2          Is brother Jesus our brother or our King?
# 3                                      what is I-20?
# 4                               what is a data disk?
#
#                                     question_content  \
# 0                                         web design
# 1  What do they do for sure.  I would like to be ...
# 2
# 3  students need I 20 for being admitted in Unive...
# 4  I heard that it is possible to save files on a...
#
#                                          best_answer  \
# 0  Hey!  Re. Job. I tried to e-mail you using the...
# 1  Medical Illustrator\nMedical Illustrator. Medi...
# 2  the all being one, i'd say he's our brother. y...
# 3  an I 20 is a form that the university will giv...
# 4  i think it's a usb flashdrive. a  small, light...
#
#                                            full_text
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2  Is brother Jesus our brother or our King?  the...
# 3  what is I-20? students need I 20 for being adm...
# 4  what is a data disk? I heard that it is possib...

# %%
updated_train_df.head()
# Out:
#                                              QA Text                  Class  \
# 0  Question Title:\ni am good at web design amate...     Business & Finance
# 1  Question Title:\nMy daughter wants to be a Med...  Education & Reference
# 2  Question Title:\nIs brother Jesus our brother ...      Society & Culture
# 3  Question Title:\nwhat is I-20?\nQuestion Conte...  Education & Reference
# 4  Question Title:\nwhat is a data disk?\nQuestio...   Computers & Internet
#
#                                       question_title  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2          Is brother Jesus our brother or our King?
# 3                                      what is I-20?
# 4                               what is a data disk?
#
#                                     question_content  \
# 0                                         web design
# 1  What do they do for sure.  I would like to be ...
# 2
# 3  students need I 20 for being admitted in Unive...
# 4  I heard that it is possible to save files on a...
#
#                                          best_answer  \
# 0  Hey!  Re. Job. I tried to e-mail you using the...
# 1  Medical Illustrator\nMedical Illustrator. Medi...
# 2  the all being one, i'd say he's our brother. y...
# 3  an I 20 is a form that the university will giv...
# 4  i think it's a usb flashdrive. a  small, light...
#
#                                            full_text  \
# 0  i am good at web design amateurly. how can i e...
# 1  My daughter wants to be a Medical Illustrator....
# 2  Is brother Jesus our brother or our King?  the...
# 3  what is I-20? students need I 20 for being adm...
# 4  what is a data disk? I heard that it is possib...
#
#    question_title_char_count  question_title_word_count  \
# 0                         74                         16
# 1                         78                         14
# 2                         41                          8
# 3                         13                          3
# 4                         20                          5
#
#    question_title_sent_count  question_content_char_count  ...  \
# 0                          2                           10  ...
# 1                          2                          122  ...
# 2                          1                            0  ...
# 3                          1                           94  ...
# 4                          1                          210  ...
#
#    full_text_sent_count  question_title_lexical_diversity  \
# 0                     8                            0.9375
# 1                     8                            1.0000
# 2                     3                            0.7500
# 3                     5                            1.0000
# 4                     8                            1.0000
#
#    question_content_lexical_diversity  best_answer_lexical_diversity  \
# 0                            1.000000                       0.754386
# 1                            0.920000                       0.640244
# 2                            0.000000                       1.000000
# 3                            0.842105                       0.800000
# 4                            0.818182                       0.837209
#
#    full_text_lexical_diversity  has_url  has_email  has_html  num_qmarks  \
# 0                     0.773333    False       True     False           1
# 1                     0.660099     True      False      True           3
# 2                     0.863636    False      False     False           1
# 3                     0.677419    False      False     False           2
# 4                     0.717391    False      False     False           2
#
#    num_exclaims
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Extending EDA

# %% [markdown]
# ## Class Balance

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=updated_train_df, x="Class", order=updated_train_df["Class"].value_counts().index)
plt.xticks(rotation=90)
plt.title("Class Distribution")
plt.show()

# Print numeric distribution
updated_train_df["Class"].value_counts(normalize=True).round(3) * 100
# Out:
# Class
# Entertainment & Music     10.1
# Health                    10.1
# Sports                    10.0
# Science & Mathematics     10.0
# Computers & Internet      10.0
# Education & Reference     10.0
# Business & Finance        10.0
# Family & Relationships    10.0
# Society & Culture         10.0
# Politics & Government      9.9
# Name: proportion, dtype: float64

# %% [markdown]
# ## Per-class Text Characteristics (Compare average word count per class)

# %%
avg_word_counts = (
    updated_train_df.groupby("Class")["full_text_word_count"]
    .mean()
    .sort_values(ascending=False)
)

plt.figure(figsize=(10,4))
avg_word_counts.plot(kind="bar", color="purple")
plt.title("Average Full Text Word Count per Class")
plt.ylabel("Average Word Count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Top N-grams (takes too long to finish execution)

# %%
# def get_top_ngrams(corpus, ngram_range=(2,2), n=20):
#     vec = CountVectorizer(ngram_range=ngram_range, stop_words="english").fit(corpus)
#     bag_of_words = vec.transform(corpus)
#     sum_words = bag_of_words.sum(axis=0)
#     words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
#     return sorted(words_freq, key=lambda x: x[1], reverse=True)[:n]


# # Top bigrams
# print("Top 10 Bigrams:")
# print(get_top_ngrams(updated_train_df["full_text"], (2,2), 10))

# # Top trigrams
# print("\nTop 10 Trigrams:")
# print(get_top_ngrams(updated_train_df["full_text"], (3,3), 10))

# This cell's output:
# Top 10 Bigrams:
# [('nhttp www', np.int64(15931)), ('http www', np.int64(10477)), ('don know', np.int64(8832)), ('good luck', np.int64(6180)), ('make sure', np.int64(4881)), ('does know', np.int64(4585)), ('yahoo com', np.int64(4456)), ('don want', np.int64(4184)), ('don think', np.int64(4070)), ('ngood luck', np.int64(4019))]

# Top 10 Trigrams:
# [('com nhttp www', np.int64(2272)), ('wikipedia org wiki', np.int64(1970)), ('en wikipedia org', np.int64(1924)), ('nhttp en wikipedia', np.int64(1114)), ('ha ha ha', np.int64(1050)), ('usa usa usa', np.int64(1002)), ('html nhttp www', np.int64(818)), ('http en wikipedia', np.int64(789)), ('answers yahoo com', np.int64(760)), ('yahoo com question', np.int64(622))]

# %% [markdown]
# ## Extreme outliers (Show very long answers)

# %%
longest_samples = updated_train_df.nlargest(5, "full_text_word_count")[["full_text_word_count", "full_text"]]
longest_samples
# Out:
#         full_text_word_count  \
# 224134                  1334
# 4810                    1239
# 70977                   1205
# 49449                   1188
# 226367                  1179
#
#                                                 full_text
# 224134  Somehow I came across a very Interesting websi...
# 4810    Why are MONKS / PRIESTS expected to teach ATHE...
# 70977   To do good works or saved by the blood of Chri...
# 49449   I need LEGAL ADVICE!! You don't have to be a l...
# 226367  Players Championship PGA Colf Tounament who is...

# %% [markdown]
# ## Train vs Test comparison

# %%
# Compare class distributions
fig, axes = plt.subplots(1, 2, figsize=(14,6), sharey=True)

sns.countplot(x="Class", data=updated_train_df, order=updated_train_df["Class"].value_counts().index, ax=axes[0])
axes[0].set_title("Train Set Class Distribution")
axes[0].tick_params(axis="x", rotation=90)

sns.countplot(x="Class", data=updated_test_df, order=updated_test_df["Class"].value_counts().index, ax=axes[1])
axes[1].set_title("Test Set Class Distribution")
axes[1].tick_params(axis="x", rotation=90)

plt.tight_layout()
plt.show()

print()
# Compare word count distribution
plt.figure(figsize=(10,5))
sns.kdeplot(updated_train_df["full_text_word_count"], label="Train", fill=True)
sns.kdeplot(updated_test_df["full_text_word_count"], label="Test", fill=True)
plt.title("Train vs Test Word Count Distribution")
plt.legend()
plt.show()

# %% [markdown]
# #
